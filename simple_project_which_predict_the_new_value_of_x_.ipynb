# %% [markdown]
# Jai shree ram

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# Generate sample data
np.random.seed(0)
X = np.random.rand(100, 1)
y = 2 * X + 1 + np.random.randn(100, 1)

# %%
# Create a DataFrame using pandas
data = pd.DataFrame({'X': X.flatten(), 'y': y.flatten()})

# Visualize the data
plt.scatter(data['X'], data['y'])
plt.xlabel('X')
plt.ylabel('y')
plt.title('Scatter plot of sample data')
plt.show()

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data['X'], data['y'], test_size=0.2, random_state=42)

# %%
# Create and train the linear regression model
model = LinearRegression()
model.fit(X_train.values.reshape(-1, 1), y_train.values)
# Out:
# LinearRegression()

# %%
# Make predictions on the test set
y_pred = model.predict(X_test.values.reshape(-1, 1))

# Visualize the results
plt.scatter(X_test, y_test, label='Actual')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression')
plt.legend()
plt.show()

# %%
# Use the trained model for prediction
new_X = np.array([[0.6], [0.8], [1.0]])
predicted_values = model.predict(new_X)

print("Predicted values:")
for i in range(len(new_X)):
    print(f"For X = {new_X[i][0]}, predicted y = {predicted_values[i]}")
# Out:
# Predicted values:
# For X = 0.6, predicted y = 2.3946511099173033
# For X = 0.8, predicted y = 2.79075475031926
# For X = 1.0, predicted y = 3.1868583907212154
